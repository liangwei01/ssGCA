# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_context("notebook", rc={"lines.linewidth": 3})
##################################################
plt.style.use('tableau-colorblind10')
##################################################

# %%
cate = "primaryNivo"
edge_os = pd.read_csv(f"./cox_result/cox_result_{cate}_os.txt",index_col=0)
edge_pfs = pd.read_csv(f"./cox_result/cox_result_{cate}_pfs.txt",index_col=0)


ano = ".positive."
resos = pd.read_csv(f"../connectivity/{cate}{ano}_os_significant_nodes_by_connectivity.txt")
respfs = pd.read_csv(f"../connectivity/{cate}{ano}_pfs_significant_nodes_by_connectivity.txt")

ano = ".negative."
resos1 = pd.read_csv(f"../connectivity/{cate}{ano}_os_significant_nodes_by_connectivity.txt")
respfs1 = pd.read_csv(f"../connectivity/{cate}{ano}_pfs_significant_nodes_by_connectivity.txt")

#degree_os = pd.read_csv(f"../degree/pn_os_significant_nodes_by_degree.txt")
#degree_pfs = pd.read_csv(f"../degree/pn_os_significant_nodes_by_degree.txt")

# %%
p = 0.01
a = [ j for i in edge_os[edge_os['p']<p ].index.tolist() for j in i.split("_")]
b = [ j for i in edge_pfs[edge_pfs['p']<p ].index.tolist() for j in i.split("_")]
c = resos[resos['p']<p ]["covariate"].tolist() + resos1[resos1['p']<p ]["covariate"].tolist()
d = respfs[respfs['p']<p ]["covariate"].tolist() + respfs1[respfs1['p']<p ]["covariate"].tolist()

#e = degree_os[degree_os['p']<p ]["covariate"].tolist()
#f = degree_pfs[degree_pfs['p']<p ]["covariate"].tolist()

# %%
resos[resos['p']<p ]
# Out:
#        covariate      coef   exp(coef)  se(coef)  coef lower 95%  \
# 1        MIR31HG  1.473192    4.363139  0.462227        0.567243
# 6      SFTPD-AS1  1.882546    6.570209  0.519617        0.864115
# 76    MIS18A-AS1  2.283832    9.814214  0.638372        1.032646
# 79    DDX39B-AS1  1.931860    6.902339  0.646446        0.664849
# 178        OXLD1 -3.237165    0.039275  1.113232       -5.419061
# ...          ...       ...         ...       ...             ...
# 4821      GOLGA3  3.593284   36.353279  1.361503        0.924788
# 4873        BRI3  3.758643   42.890205  1.229940        1.348006
# 4879       CCT6A  3.274871   26.439818  1.225019        0.873878
# 4941   LINC01278  3.847420   46.871983  1.189272        1.516490
# 4975         LAT  4.749978  115.581735  1.126111        2.542841
#
#       coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  cmp to  \
# 1           2.379141             1.763399            10.795621     0.0
# ...

# %%
from venny4py.venny4py import *

#fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(3, 3))
#dict of sets
sets = {
    'Edge-OS': set(a ),
    'Edge-PFS': set(b),
    'Connectivity-OS': set(c),
    'Connectivity-PFS': set(d)}
    
venny4py(sets=sets)
plt.tight_layout()
plt.savefig(f'f4_{cate}_edges)genes_venn.svg',dpi=600)
plt.savefig(f'f4_{cate}_edges)genes_venn.tif',dpi=600)
