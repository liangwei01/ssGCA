# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
cate = "primaryNivo"
ano = ".negative."
resos = pd.read_csv(f"{cate}{ano}_os_significant_nodes_by_connectivity.txt")
respfs = pd.read_csv(f"{cate}{ano}_pfs_significant_nodes_by_connectivity.txt")
psignificant_gene = set(resos[resos["p"]<0.01]["covariate"].tolist()).intersection(respfs[respfs["p"]<0.01]["covariate"].tolist())
print(len(psignificant_gene))

cate = "primaryEver"
resos = pd.read_csv(f"{cate}{ano}_os_significant_nodes_by_connectivity.txt")
respfs = pd.read_csv(f"{cate}{ano}_pfs_significant_nodes_by_connectivity.txt")
pesignificant_gene = set(resos[resos["p"]<0.01]["covariate"].tolist()).intersection(respfs[respfs["p"]<0.01]["covariate"].tolist())
print(len(pesignificant_gene))

cate = "metaNivo"
resos = pd.read_csv(f"{cate}{ano}_os_significant_nodes_by_connectivity.txt")
respfs = pd.read_csv(f"{cate}{ano}_pfs_significant_nodes_by_connectivity.txt")
mnsignificant_gene = set(resos[resos["p"]<0.01]["covariate"].tolist()).intersection(respfs[respfs["p"]<0.01]["covariate"].tolist())
print(len(mnsignificant_gene))


cate = "metaEver"
resos = pd.read_csv(f"{cate}{ano}_os_significant_nodes_by_connectivity.txt")
respfs = pd.read_csv(f"{cate}{ano}_pfs_significant_nodes_by_connectivity.txt")
mesignificant_gene = set(resos[resos["p"]<0.01]["covariate"].tolist()).intersection(respfs[respfs["p"]<0.01]["covariate"].tolist())
print(len(mesignificant_gene))

b = list(psignificant_gene) + list(pesignificant_gene) + list(mnsignificant_gene) + list(mesignificant_gene)
print(len(set(b)))
# Out:
# 48
# 39
# 17
# 0
# 104

# %%
from venny4py.venny4py import *

#dict of sets
sets = {
    'pN': set(psignificant_gene),
    'pE': set(pesignificant_gene),
    'mN': set(mnsignificant_gene),
    'mE': set(mesignificant_gene)}
    
venny4py(sets=sets)
